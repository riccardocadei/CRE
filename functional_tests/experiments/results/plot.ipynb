# %%
import pyreadr

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
cdr = pyreadr.read_r('discovery_cdr_1000s_2r.rdata')["causal_decision_rules"]
cdr.replace("NaN","0", inplace=True)
cdr.iloc[:,1:] = cdr.iloc[:,1:].astype(float)
cdr
# Out:
# /var/folders/hs/p6804kqx5h90bwfczqghpxww0000gn/T/ipykernel_45643/2611351456.py:3: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   cdr.iloc[:,1:] = cdr.iloc[:,1:].astype(float)
#          method  effect_size  seed       IoU  Precision  Recall
# 0    CRE (AIPW)          0.0   1.0  0.000000        0.0     0.0
# 1           HCT          0.0   1.0  0.000000        0.0     0.0
# 2    CRE (AIPW)          0.0   2.0  0.000000        0.0     0.0
# 3           HCT          0.0   2.0  0.000000        0.0     0.0
# 4    CRE (AIPW)          0.0   3.0  0.000000        0.0     0.0
# ..          ...          ...   ...       ...        ...     ...
# 125         HCT          3.0   3.0  0.000000        0.0     0.0
# 126  CRE (AIPW)          3.0   4.0  0.333333        0.5     0.5
# ...

# %%
em = pyreadr.read_r('discovery_em_1000s_2r.rdata')["effect_modifiers"]
em.replace("NaN","0", inplace=True)
em.iloc[:,1:] = em.iloc[:,1:].astype(float)
em
# Out:
# /var/folders/hs/p6804kqx5h90bwfczqghpxww0000gn/T/ipykernel_45643/4030179399.py:3: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   em.iloc[:,1:] = em.iloc[:,1:].astype(float)
#          method  effect_size  seed   IoU  Precision  Recall
# 0    CRE (AIPW)          0.0   1.0  0.00   0.000000     0.0
# 1           HCT          0.0   1.0  0.00   0.000000     0.0
# 2    CRE (AIPW)          0.0   2.0  0.00   0.000000     0.0
# 3           HCT          0.0   2.0  0.00   0.000000     0.0
# 4    CRE (AIPW)          0.0   3.0  0.00   0.000000     0.0
# ..          ...          ...   ...   ...        ...     ...
# 125         HCT          3.0   3.0  0.00   0.000000     0.0
# 126  CRE (AIPW)          3.0   4.0  0.40   0.666667     0.5
# ...

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 3), layout='constrained')
fig.suptitle('Discovery - Effect Modifiers')

sns.lineplot(data=em, x="effect_size", y="IoU", hue="method", ax=ax[0])
ax[0].set_xlabel('Effect Size') 
ax[0].set_ylabel('IoU') 
ax[0].set_ylim((0,1))
ax[0].legend(loc='upper left');  

sns.lineplot(data=em, x="effect_size", y="Precision", hue="method", ax=ax[1])
ax[1].set_xlabel('Effect Size')  
ax[1].set_ylabel('Precision')  
ax[1].set_ylim((0,1))
ax[1].legend(loc='upper left');  

sns.lineplot(data=em, x="effect_size", y="Recall", hue="method", ax=ax[2])
ax[2].set_xlabel('Effect Size') 
ax[2].set_ylabel('Recall')  
ax[2].set_ylim((0,1))
ax[2].legend(loc='upper left');

# %%
fig, ax = plt.subplots(1,3,figsize=(10, 3), layout='constrained')
fig.suptitle('Discovery - Causal Decision Rules')

sns.lineplot(data=cdr, x="effect_size", y="IoU", hue="method", ax=ax[0])
ax[0].set_xlabel('Effect Size')  
ax[0].set_ylabel('IoU') 
ax[0].set_ylim((0,1)) 
ax[0].legend(loc='upper left');

sns.lineplot(data=cdr, x="effect_size", y="Precision", hue="method", ax=ax[1])
ax[1].set_xlabel('Effect Size')  
ax[1].set_ylabel('Precision') 
ax[1].set_ylim((0,1)) 
ax[1].legend(loc='upper left');  

sns.lineplot(data=cdr, x="effect_size", y="Recall", hue="method", ax=ax[2])
ax[2].set_xlabel('Effect Size')  
ax[2].set_ylabel('Recall')  
ax[2].set_ylim((0,1))
ax[2].legend(loc='upper left');
